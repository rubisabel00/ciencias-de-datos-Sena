# %%
pip install opencv-python

# %%
pip install ultralytics

# %%
# Importar librerías
from ultralytics import YOLO  # Importar el modelo YOLO de Ultralytics
import cv2                   # Importar la biblioteca OpenCV
import math                  # Importar el módulo math para operaciones matemáticas

# Iniciar la webcam
cap = cv2.VideoCapture(0)    # Abrir la cámara predeterminada (índice 0)
cap.set(3, 640)               # Establecer el ancho del fotograma en 640 píxeles
cap.set(4, 480)               # Establecer la altura del fotograma en 480 píxeles

# Cargar el modelo YOLO
model = YOLO("yolo-Weights/yolov8n.pt")  # Cargar el modelo YOLOv8 con pesos pre-entrenados

# Definir las clases de objetos para la detección
classNames = ["persona", "bicicleta", "coche", "motocicleta", "avión", "autobús", "tren", "camión", "bote",
              "semáforo", "boca de incendios", "señal de stop", "parquímetro", "banco", "pájaro", "gato",
              "perro", "caballo", "oveja", "vaca", "elefante", "oso", "cebra", "jirafa", "mochila", "paraguas",
              "bolso", "corbata", "maleta", "frisbee", "esquís", "snowboard", "balón deportivo", "cometa", "bate de béisbol",
              "guante de béisbol", "monopatin", "tabla de surf", "raqueta de tenis", "botella", "copa de vino", "taza",
              "tenedor", "cuchillo", "cuchara", "cuenco", "plátano", "manzana", "sándwich", "naranja", "brócoli",
              "zanahoria", "perrito caliente", "pizza", "donut", "pastel", "silla", "sofá", "planta en maceta", "cama",
              "mesa de comedor", "retrete", "monitor de TV", "ordenador portátil", "ratón", "control remoto", "teclado", "telefono movil",
              "microondas", "horno", "tostadora", "fregadero", "refrigerador", "libro", "reloj", "florero", "tijeras",
              "oso de peluche", "secador de pelo", "cepillo de dientes"
              ]

# Bucle infinito para capturar continuamente fotogramas de la cámara
while True:
    # Leer un fotograma de la cámara
    success, img = cap.read()

    # Realizar la detección de objetos utilizando el modelo YOLO en el fotograma capturado
    results = model(img, stream=True)

    # Iterar a través de los resultados de la detección de objetos
    for r in results:
        boxes = r.boxes  # Extraer las cajas delimitadoras de los objetos detectados

        # Iterar a través de cada caja delimitadora
        for box in boxes:
            # Extraer coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convertir a valores enteros

            # Dibuja la caja delimitadora en el fotograma
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Calcular e imprimir la puntuación de confianza de la detección
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confianza --->", confidence)

            # Determinar e imprimir el nombre de la clase del objeto detectado
            cls = int(box.cls[0])
            print("Nombre de la clase -->", classNames[cls])

            # Dibujar texto indicando el nombre de la clase en el fotograma
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX # Tipo de fuente para el texto
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness) # Dibujar el nombre de la clase en el fotograma

    # Mostrar el fotograma con los objetos detectados en una ventana llamada "Cam"
    cv2.imshow('Cam', img)

    # Comprobar si se presionó la tecla 'q' para salir del bucle
    if cv2.waitKey(1) == ord('q'):
        break

# Liberar la cámara
cap.release()

# Cerrar todas las ventanas de OpenCV
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 persons, 1982.5ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> persona
# Speed: 177.6ms preprocess, 1982.5ms inference, 165.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 264.6ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 26.7ms preprocess, 264.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.7ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 7.8ms preprocess, 223.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 236.0ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Speed: 4.4ms preprocess, 236.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 221.2ms
# Confianza ---> 0.56
# Nombre de la clase --> persona
# Confianza ---> 0.54
# Nombre de la clase --> persona
# Speed: 5.5ms preprocess, 221.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 227.3ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Speed: 5.4ms preprocess, 227.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 226.2ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.42
# Nombre de la clase --> persona
# Speed: 3.5ms preprocess, 226.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.4ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 4.4ms preprocess, 226.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 221.2ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 4.1ms preprocess, 221.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 233.6ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.55
# Nombre de la clase --> persona
# Speed: 7.5ms preprocess, 233.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 221.9ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Speed: 11.1ms preprocess, 221.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 366.9ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Confianza ---> 0.63
# Nombre de la clase --> gato
# Speed: 5.7ms preprocess, 366.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 221.5ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Confianza ---> 0.7
# Nombre de la clase --> gato
# Speed: 3.4ms preprocess, 221.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.0ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Speed: 9.7ms preprocess, 224.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.2ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 7.6ms preprocess, 223.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 3.4ms preprocess, 220.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.3ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Speed: 8.7ms preprocess, 218.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.2ms
# Confianza ---> 0.68
# Nombre de la clase --> persona
# Speed: 10.5ms preprocess, 214.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.2ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 7.3ms preprocess, 208.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Speed: 4.1ms preprocess, 206.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.6ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Speed: 5.8ms preprocess, 212.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.6ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Speed: 8.8ms preprocess, 219.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 224.5ms
# Confianza ---> 0.75
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 10.9ms preprocess, 224.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.9ms
# Confianza ---> 0.48
# Nombre de la clase --> persona
# Speed: 7.9ms preprocess, 216.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.7ms
# Confianza ---> 0.6
# Nombre de la clase --> persona
# Speed: 3.9ms preprocess, 217.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 224.1ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 8.5ms preprocess, 224.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 257.4ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> gato
# Speed: 7.6ms preprocess, 257.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 427.7ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 15.6ms preprocess, 427.7ms inference, 25.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 356.3ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Speed: 15.3ms preprocess, 356.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 344.0ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Speed: 3.8ms preprocess, 344.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.4ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 33.7ms preprocess, 325.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 230.6ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Confianza ---> 0.64
# Nombre de la clase --> persona
# Speed: 11.1ms preprocess, 230.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 233.4ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 233.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 216.4ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Confianza ---> 0.58
# Nombre de la clase --> persona
# Speed: 8.4ms preprocess, 216.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 221.2ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.59
# Nombre de la clase --> persona
# Speed: 6.4ms preprocess, 221.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.2ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 5.4ms preprocess, 230.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 218.2ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> gato
# Confianza ---> 0.36
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 218.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 234.6ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.55
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> monitor de TV
# Speed: 4.8ms preprocess, 234.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 236.3ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.6
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 4.1ms preprocess, 236.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 256.1ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.53
# Nombre de la clase --> persona
# Speed: 6.6ms preprocess, 256.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 228.4ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.67
# Nombre de la clase --> persona
# Speed: 5.5ms preprocess, 228.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.3ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 4.6ms preprocess, 231.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.5ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 3.9ms preprocess, 243.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.9ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 7.5ms preprocess, 227.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.3ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 6.8ms preprocess, 227.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.0ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 5.1ms preprocess, 210.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.3ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 216.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 220.6ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.45
# Nombre de la clase --> monitor de TV
# Speed: 6.8ms preprocess, 220.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 227.8ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Speed: 5.0ms preprocess, 227.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 219.3ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.46
# Nombre de la clase --> monitor de TV
# Speed: 3.8ms preprocess, 219.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 233.4ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> monitor de TV
# Speed: 8.1ms preprocess, 233.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.2ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 3.7ms preprocess, 217.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.5ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 4.2ms preprocess, 235.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 227.1ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.37
# Nombre de la clase --> persona
# Speed: 6.6ms preprocess, 227.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 242.8ms
# Confianza ---> 0.77
# Nombre de la clase --> persona
# Confianza ---> 0.7
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.47
# Nombre de la clase --> teléfono móvil
# Speed: 4.3ms preprocess, 242.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 234.9ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.81
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.54
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 4.7ms preprocess, 234.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 235.6ms
# Confianza ---> 0.8
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 4.7ms preprocess, 235.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 229.4ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.79
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.38
# Nombre de la clase --> teléfono móvil
# Speed: 6.6ms preprocess, 229.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 235.6ms
# Confianza ---> 0.76
# Nombre de la clase --> persona
# Confianza ---> 0.74
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.4
# Nombre de la clase --> teléfono móvil
# Speed: 4.8ms preprocess, 235.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 242.7ms
# Confianza ---> 0.79
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.57
# Nombre de la clase --> teléfono móvil
# Speed: 5.9ms preprocess, 242.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 219.6ms
# Confianza ---> 0.88
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.74
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> teléfono móvil
# Speed: 7.4ms preprocess, 219.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 210.9ms
# Confianza ---> 0.93
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.76
# Nombre de la clase --> persona
# Confianza ---> 0.44
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.4
# Nombre de la clase --> persona
# Speed: 5.6ms preprocess, 210.9ms inference, 79.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 214.8ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.69
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.39
# Nombre de la clase --> teléfono móvil
# Speed: 3.5ms preprocess, 214.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 231.6ms
# Confianza ---> 0.92
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.77
# Nombre de la clase --> persona
# Speed: 3.5ms preprocess, 231.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 223.7ms
# Confianza ---> 0.9
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.78
# Nombre de la clase --> persona
# Confianza ---> 0.37
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 223.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 219.8ms
# Confianza ---> 0.86
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.77
# Nombre de la clase --> persona
# Speed: 5.6ms preprocess, 219.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 228.7ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.62
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.33
# Nombre de la clase --> persona
# Speed: 4.3ms preprocess, 228.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 221.4ms
# Confianza ---> 0.78
# Nombre de la clase --> persona
# Confianza ---> 0.61
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.31
# Nombre de la clase --> persona
# Speed: 3.3ms preprocess, 221.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 230.3ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.68
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 5.7ms preprocess, 230.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 231.9ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.28
# Nombre de la clase --> persona
# Speed: 4.9ms preprocess, 231.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 239.8ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.72
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 7.3ms preprocess, 239.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 252.4ms
# Confianza ---> 0.85
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.77
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> persona
# Speed: 6.3ms preprocess, 252.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.4ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 243.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.4ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 235.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 231.6ms
# Confianza ---> 0.67
# Nombre de la clase --> persona
# Confianza ---> 0.34
# Nombre de la clase --> refrigerador
# Speed: 6.0ms preprocess, 231.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 223.7ms
# Confianza ---> 0.66
# Nombre de la clase --> persona
# Confianza ---> 0.61
# Nombre de la clase --> persona
# Confianza ---> 0.4
# Nombre de la clase --> persona
# Speed: 4.1ms preprocess, 223.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 215.8ms
# Confianza ---> 0.76
# Nombre de la clase --> persona
# Confianza ---> 0.54
# Nombre de la clase --> persona
# Speed: 7.1ms preprocess, 215.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 218.5ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.75
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 218.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 220.6ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> persona
# Speed: 3.5ms preprocess, 220.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 216.7ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Speed: 5.5ms preprocess, 216.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 249.7ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> persona
# Speed: 4.1ms preprocess, 249.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 243.2ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.31
# Nombre de la clase --> persona
# Speed: 9.8ms preprocess, 243.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 225.3ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> persona
# Speed: 4.8ms preprocess, 225.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 223.8ms
# Confianza ---> 0.66
# Nombre de la clase --> persona
# Confianza ---> 0.53
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.4
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.34
# Nombre de la clase --> persona
# Speed: 7.5ms preprocess, 223.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 225.7ms
# Confianza ---> 0.69
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> teléfono móvil
# Speed: 3.6ms preprocess, 225.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 227.2ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.52
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.37
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.33
# Nombre de la clase --> teléfono móvil
# Speed: 5.7ms preprocess, 227.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 224.8ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.34
# Nombre de la clase --> teléfono móvil
# Speed: 9.0ms preprocess, 224.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 232.1ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.53
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.37
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 4.9ms preprocess, 232.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.6ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 8.1ms preprocess, 250.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 228.3ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 6.7ms preprocess, 228.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.5ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 5.6ms preprocess, 227.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 218.3ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> monitor de TV
# Speed: 9.9ms preprocess, 218.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.9ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 212.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.2ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 3.5ms preprocess, 218.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.2ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 213.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 4.3ms preprocess, 211.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cat, 1 cup, 1 tv, 217.4ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.47
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> taza
# Confianza ---> 0.33
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> gato
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 4.7ms preprocess, 217.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 221.2ms
# Confianza ---> 0.93
# Nombre de la clase --> taza
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.62
# Nombre de la clase --> persona
# Speed: 7.7ms preprocess, 221.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 223.7ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.66
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> persona
# Speed: 3.3ms preprocess, 223.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 220.7ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.54
# Nombre de la clase --> gato
# Confianza ---> 0.33
# Nombre de la clase --> persona
# Speed: 4.2ms preprocess, 220.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cat, 2 toilets, 221.5ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.58
# Nombre de la clase --> retrete
# Confianza ---> 0.37
# Nombre de la clase --> retrete
# Confianza ---> 0.32
# Nombre de la clase --> gato
# Confianza ---> 0.31
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 5.1ms preprocess, 221.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 toilet, 225.5ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.45
# Nombre de la clase --> persona
# Confianza ---> 0.4
# Nombre de la clase --> retrete
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 6.7ms preprocess, 225.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 217.6ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.51
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 217.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toilet, 375.4ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> retrete
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 4.9ms preprocess, 375.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toilet, 235.9ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.41
# Nombre de la clase --> retrete
# Speed: 6.2ms preprocess, 235.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toilet, 1 sink, 237.3ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.44
# Nombre de la clase --> fregadero
# Confianza ---> 0.37
# Nombre de la clase --> retrete
# Confianza ---> 0.35
# Nombre de la clase --> persona
# Speed: 6.1ms preprocess, 237.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 sink, 237.6ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.44
# Nombre de la clase --> taza
# Confianza ---> 0.39
# Nombre de la clase --> fregadero
# Speed: 5.1ms preprocess, 237.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 219.5ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.51
# Nombre de la clase --> persona
# Confianza ---> 0.41
# Nombre de la clase --> persona
# Confianza ---> 0.34
# Nombre de la clase --> taza
# Speed: 5.5ms preprocess, 219.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 tv, 217.1ms
# Confianza ---> 0.78
# Nombre de la clase --> persona
# Confianza ---> 0.74
# Nombre de la clase --> taza
# Confianza ---> 0.34
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> persona
# Speed: 3.6ms preprocess, 217.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 220.4ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.72
# Nombre de la clase --> taza
# Confianza ---> 0.53
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 6.5ms preprocess, 220.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 refrigerator, 212.0ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.37
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> refrigerador
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 4.2ms preprocess, 212.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 219.1ms
# Confianza ---> 0.72
# Nombre de la clase --> persona
# Confianza ---> 0.66
# Nombre de la clase --> persona
# Speed: 5.9ms preprocess, 219.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 220.3ms
# Confianza ---> 0.62
# Nombre de la clase --> persona
# Confianza ---> 0.53
# Nombre de la clase --> persona
# Confianza ---> 0.46
# Nombre de la clase --> taza
# Confianza ---> 0.42
# Nombre de la clase --> persona
# Speed: 4.6ms preprocess, 220.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 224.2ms
# Confianza ---> 0.75
# Nombre de la clase --> taza
# Confianza ---> 0.72
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 4.7ms preprocess, 224.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 toilet, 220.8ms
# Confianza ---> 0.7
# Nombre de la clase --> taza
# Confianza ---> 0.7
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> retrete
# Speed: 5.2ms preprocess, 220.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 221.2ms
# Confianza ---> 0.66
# Nombre de la clase --> persona
# Confianza ---> 0.64
# Nombre de la clase --> persona
# Confianza ---> 0.44
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> persona
# Speed: 7.1ms preprocess, 221.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 toilet, 231.8ms
# Confianza ---> 0.61
# Nombre de la clase --> persona
# Confianza ---> 0.46
# Nombre de la clase --> retrete
# Confianza ---> 0.31
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> persona
# Speed: 3.9ms preprocess, 231.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 tv, 236.6ms
# Confianza ---> 0.65
# Nombre de la clase --> persona
# Confianza ---> 0.61
# Nombre de la clase --> taza
# Confianza ---> 0.37
# Nombre de la clase --> monitor de TV
# Speed: 7.5ms preprocess, 236.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 bowl, 1 toothbrush, 228.8ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.56
# Nombre de la clase --> cepillo de dientes
# Confianza ---> 0.41
# Nombre de la clase --> cuenco
# Confianza ---> 0.35
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> taza
# Speed: 3.5ms preprocess, 228.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 227.2ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> monitor de TV
# Speed: 5.8ms preprocess, 227.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 tv, 237.1ms
# Confianza ---> 0.63
# Nombre de la clase --> persona
# Confianza ---> 0.47
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.28
# Nombre de la clase --> taza
# Speed: 6.0ms preprocess, 237.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 toilet, 1 tv, 244.8ms
# Confianza ---> 0.56
# Nombre de la clase --> persona
# Confianza ---> 0.48
# Nombre de la clase --> persona
# Confianza ---> 0.43
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.3
# Nombre de la clase --> retrete
# Speed: 8.6ms preprocess, 244.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 236.7ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.83
# Nombre de la clase --> taza
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 7.6ms preprocess, 236.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 tv, 216.4ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.54
# Nombre de la clase --> taza
# Confianza ---> 0.53
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.27
# Nombre de la clase --> persona
# Speed: 5.1ms preprocess, 216.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 215.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.82
# Nombre de la clase --> taza
# Confianza ---> 0.49
# Nombre de la clase --> persona
# Speed: 3.9ms preprocess, 215.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 212.3ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.49
# Nombre de la clase --> persona
# Confianza ---> 0.34
# Nombre de la clase --> taza
# Speed: 6.0ms preprocess, 212.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 toilet, 222.9ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> retrete
# Confianza ---> 0.29
# Nombre de la clase --> taza
# Speed: 3.2ms preprocess, 222.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 tv, 221.8ms
# Confianza ---> 0.78
# Nombre de la clase --> persona
# Confianza ---> 0.61
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.47
# Nombre de la clase --> taza
# Confianza ---> 0.4
# Nombre de la clase --> persona
# Speed: 3.7ms preprocess, 221.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 tv, 217.8ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.28
# Nombre de la clase --> taza
# Speed: 9.2ms preprocess, 217.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 tv, 1 teddy bear, 219.8ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Confianza ---> 0.37
# Nombre de la clase --> persona
# Confianza ---> 0.34
# Nombre de la clase --> oso de peluche
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.26
# Nombre de la clase --> taza
# Speed: 9.0ms preprocess, 219.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 225.8ms
# Confianza ---> 0.71
# Nombre de la clase --> persona
# Confianza ---> 0.56
# Nombre de la clase --> persona
# Confianza ---> 0.54
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> taza
# Speed: 3.8ms preprocess, 225.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 228.3ms
# Confianza ---> 0.76
# Nombre de la clase --> persona
# Confianza ---> 0.31
# Nombre de la clase --> persona
# Speed: 6.1ms preprocess, 228.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 247.8ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 9.1ms preprocess, 247.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 235.5ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> monitor de TV
# Speed: 3.7ms preprocess, 235.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 225.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Speed: 7.1ms preprocess, 225.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 227.8ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.56
# Nombre de la clase --> monitor de TV
# Speed: 4.6ms preprocess, 227.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.3ms
# Confianza ---> 0.91
# Nombre de la clase --> persona
# Speed: 5.8ms preprocess, 238.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 273.8ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Speed: 5.3ms preprocess, 273.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.4ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 3.3ms preprocess, 220.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 250.3ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> monitor de TV
# Speed: 3.4ms preprocess, 250.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.3ms
# Confianza ---> 0.91
# Nombre de la clase --> persona
# Speed: 9.4ms preprocess, 214.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 213.7ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Speed: 4.1ms preprocess, 213.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 217.8ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.44
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.27
# Nombre de la clase --> persona
# Speed: 3.9ms preprocess, 217.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.7ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 5.3ms preprocess, 235.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 232.2ms
# Confianza ---> 0.91
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 5.5ms preprocess, 232.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 227.4ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.58
# Nombre de la clase --> persona
# Speed: 6.5ms preprocess, 227.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 218.5ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> persona
# Speed: 5.1ms preprocess, 218.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 229.5ms
# Confianza ---> 0.91
# Nombre de la clase --> persona
# Confianza ---> 0.43
# Nombre de la clase --> persona
# Speed: 3.7ms preprocess, 229.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.6ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 6.0ms preprocess, 232.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 228.8ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Speed: 4.6ms preprocess, 228.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 223.2ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.43
# Nombre de la clase --> persona
# Speed: 6.1ms preprocess, 223.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 229.5ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.57
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> monitor de TV
# Speed: 4.2ms preprocess, 229.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 240.5ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 7.4ms preprocess, 240.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 225.9ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> persona
# Speed: 6.6ms preprocess, 225.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 232.0ms
# Confianza ---> 0.71
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Speed: 6.3ms preprocess, 232.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 216.3ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Speed: 3.2ms preprocess, 216.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 234.1ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 234.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 220.6ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Speed: 8.7ms preprocess, 220.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 215.4ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Confianza ---> 0.37
# Nombre de la clase --> persona
# Speed: 3.4ms preprocess, 215.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 246.3ms
# Confianza ---> 0.74
# Nombre de la clase --> persona
# Confianza ---> 0.45
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> monitor de TV
# Speed: 9.4ms preprocess, 246.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 218.8ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Speed: 4.9ms preprocess, 218.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 dog, 1 tv, 220.0ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.34
# Nombre de la clase --> perro
# Confianza ---> 0.33
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.26
# Nombre de la clase --> gato
# Speed: 4.3ms preprocess, 220.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 224.1ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.58
# Nombre de la clase --> persona
# Speed: 5.0ms preprocess, 224.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 240.3ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> persona
# Speed: 6.3ms preprocess, 240.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 227.5ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> monitor de TV
# Speed: 7.8ms preprocess, 227.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 225.0ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 7.0ms preprocess, 225.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 226.1ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Confianza ---> 0.45
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 5.7ms preprocess, 226.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 238.3ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> monitor de TV
# Speed: 8.4ms preprocess, 238.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 227.7ms
# Confianza ---> 0.89
# Nombre de la clase --> persona
# Confianza ---> 0.4
# Nombre de la clase --> monitor de TV
# Speed: 9.9ms preprocess, 227.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.6ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 4.8ms preprocess, 235.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.8ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Speed: 6.4ms preprocess, 224.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.1ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 3.0ms preprocess, 217.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 214.7ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> persona
# Speed: 7.1ms preprocess, 214.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 3.9ms preprocess, 211.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 214.6ms
# Confianza ---> 0.67
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> monitor de TV
# Speed: 4.3ms preprocess, 214.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 234.7ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.46
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.31
# Nombre de la clase --> teléfono móvil
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 3.9ms preprocess, 234.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 228.2ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> monitor de TV
# Speed: 3.6ms preprocess, 228.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.3ms
# Confianza ---> 0.75
# Nombre de la clase --> persona
# Speed: 5.2ms preprocess, 213.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 220.0ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.31
# Nombre de la clase --> teléfono móvil
# Speed: 6.8ms preprocess, 220.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 228.5ms
# Confianza ---> 0.69
# Nombre de la clase --> persona
# Confianza ---> 0.31
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> monitor de TV
# Speed: 4.0ms preprocess, 228.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 230.4ms
# Confianza ---> 0.72
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> persona
# Speed: 3.3ms preprocess, 230.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 230.7ms
# Confianza ---> 0.78
# Nombre de la clase --> persona
# Confianza ---> 0.49
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 3.6ms preprocess, 230.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 231.9ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Speed: 8.9ms preprocess, 231.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 234.8ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.42
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.34
# Nombre de la clase --> persona
# Speed: 5.2ms preprocess, 234.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 239.4ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Speed: 9.3ms preprocess, 239.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 236.6ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Speed: 4.8ms preprocess, 236.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 221.0ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 7.3ms preprocess, 221.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 220.3ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> monitor de TV
# ...
#
# 0: 480x640 1 person, 254.1ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 4.3ms preprocess, 254.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 256.3ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 256.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 262.3ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 6.2ms preprocess, 262.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 283.5ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 4.7ms preprocess, 283.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 279.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 14.5ms preprocess, 279.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 230.3ms
# Confianza ---> 0.7
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> persona
# Speed: 3.5ms preprocess, 230.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 243.1ms
# Confianza ---> 0.78
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> monitor de TV
# Speed: 5.0ms preprocess, 243.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 223.5ms
# Confianza ---> 0.77
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Speed: 5.6ms preprocess, 223.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.7ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Speed: 6.5ms preprocess, 235.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 230.6ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Speed: 4.4ms preprocess, 230.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.5ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 11.7ms preprocess, 231.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 258.8ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 5.2ms preprocess, 258.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.2ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Speed: 6.2ms preprocess, 211.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.5ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 5.4ms preprocess, 219.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 245.9ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 4.5ms preprocess, 245.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 240.3ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Speed: 3.8ms preprocess, 240.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 359.5ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 4.7ms preprocess, 359.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 230.1ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.38
# Nombre de la clase --> monitor de TV
# Speed: 3.2ms preprocess, 230.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 223.7ms
# Confianza ---> 0.81
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> monitor de TV
# Speed: 5.6ms preprocess, 223.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 221.2ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> monitor de TV
# Speed: 4.4ms preprocess, 221.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 247.3ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.45
# Nombre de la clase --> monitor de TV
# Confianza ---> 0.3
# Nombre de la clase --> monitor de TV
# Speed: 3.6ms preprocess, 247.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 238.9ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Confianza ---> 0.36
# Nombre de la clase --> monitor de TV
# Speed: 3.8ms preprocess, 238.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 246.6ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.3
# Nombre de la clase --> monitor de TV
# Speed: 5.5ms preprocess, 246.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 236.2ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 4.1ms preprocess, 236.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 235.5ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.39
# Nombre de la clase --> monitor de TV
# Speed: 5.2ms preprocess, 235.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 244.9ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.48
# Nombre de la clase --> monitor de TV
# Speed: 5.6ms preprocess, 244.9ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 243.0ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> monitor de TV
# Speed: 5.4ms preprocess, 243.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 212.4ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.43
# Nombre de la clase --> monitor de TV
# Speed: 5.5ms preprocess, 212.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 252.6ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.43
# Nombre de la clase --> monitor de TV
# Speed: 9.7ms preprocess, 252.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 278.4ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 3.3ms preprocess, 278.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.3ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 5.6ms preprocess, 312.3ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.4ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 5.6ms preprocess, 255.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 277.3ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 9.1ms preprocess, 277.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 291.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.28
# Nombre de la clase --> ordenador portátil
# Speed: 6.5ms preprocess, 291.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 283.6ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Speed: 5.0ms preprocess, 283.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.2ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Speed: 6.1ms preprocess, 238.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 240.2ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Speed: 6.8ms preprocess, 240.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 225.2ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.44
# Nombre de la clase --> monitor de TV
# Speed: 3.5ms preprocess, 225.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 226.3ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.45
# Nombre de la clase --> monitor de TV
# Speed: 3.9ms preprocess, 226.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 220.2ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.37
# Nombre de la clase --> monitor de TV
# Speed: 3.6ms preprocess, 220.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 260.1ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 12.0ms preprocess, 260.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 241.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Confianza ---> 0.32
# Nombre de la clase --> monitor de TV
# Speed: 6.3ms preprocess, 241.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 234.9ms
# Confianza ---> 0.87
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> monitor de TV
# Speed: 3.6ms preprocess, 234.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.3ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 4.7ms preprocess, 251.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 234.3ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Confianza ---> 0.33
# Nombre de la clase --> monitor de TV
# Speed: 8.5ms preprocess, 234.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.3ms
# Confianza ---> 0.83
# Nombre de la clase --> persona
# Speed: 4.9ms preprocess, 227.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.0ms
# Confianza ---> 0.85
# Nombre de la clase --> persona
# Speed: 8.9ms preprocess, 214.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 221.1ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Confianza ---> 0.27
# Nombre de la clase --> monitor de TV
# Speed: 3.7ms preprocess, 221.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.6ms
# Confianza ---> 0.84
# Nombre de la clase --> persona
# Speed: 3.3ms preprocess, 219.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 217.9ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> monitor de TV
# Speed: 5.1ms preprocess, 217.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.2ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 3.5ms preprocess, 232.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 228.4ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 4.8ms preprocess, 228.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.2ms
# Confianza ---> 0.92
# Nombre de la clase --> persona
# Speed: 3.2ms preprocess, 222.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.7ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 7.7ms preprocess, 223.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 283.1ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 4.2ms preprocess, 283.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 379.9ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 9.3ms preprocess, 379.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.0ms
# Confianza ---> 0.92
# Nombre de la clase --> persona
# Speed: 6.6ms preprocess, 225.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.0ms
# Confianza ---> 0.92
# Nombre de la clase --> persona
# Speed: 5.4ms preprocess, 255.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 252.2ms
# Confianza ---> 0.9
# Nombre de la clase --> persona
# Speed: 7.0ms preprocess, 252.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 254.5ms
# Confianza ---> 0.93
# Nombre de la clase --> persona
# Speed: 6.0ms preprocess, 254.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.4ms
# Confianza ---> 0.93
# Nombre de la clase --> persona
# Speed: 6.0ms preprocess, 226.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 226.6ms
# Confianza ---> 0.91
# Nombre de la clase --> persona
# Confianza ---> 0.4
# Nombre de la clase --> monitor de TV
# Speed: 6.0ms preprocess, 226.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 221.4ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.5
# Nombre de la clase --> monitor de TV
# Speed: 4.3ms preprocess, 221.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 215.2ms
# Confianza ---> 0.79
# Nombre de la clase --> persona
# Confianza ---> 0.4
# Nombre de la clase --> monitor de TV
# Speed: 7.2ms preprocess, 215.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.5ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 218.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 refrigerators, 225.8ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.48
# Nombre de la clase --> refrigerador
# Confianza ---> 0.26
# Nombre de la clase --> refrigerador
# Speed: 4.4ms preprocess, 225.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 227.2ms
# Confianza ---> 0.82
# Nombre de la clase --> persona
# Confianza ---> 0.51
# Nombre de la clase --> persona
# Confianza ---> 0.31
# Nombre de la clase --> monitor de TV
# Speed: 3.3ms preprocess, 227.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 245.7ms
# Confianza ---> 0.77
# Nombre de la clase --> persona
# Confianza ---> 0.31
# Nombre de la clase --> monitor de TV
# Speed: 4.1ms preprocess, 245.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 240.4ms
# Confianza ---> 0.73
# Nombre de la clase --> persona
# Confianza ---> 0.29
# Nombre de la clase --> persona
# Speed: 6.3ms preprocess, 240.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.0ms
# Confianza ---> 0.8
# Nombre de la clase --> persona
# Speed: 5.0ms preprocess, 224.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 231.2ms
# Confianza ---> 0.86
# Nombre de la clase --> persona
# Confianza ---> 0.42
# Nombre de la clase --> monitor de TV
# Speed: 3.6ms preprocess, 231.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 232.4ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.35
# Nombre de la clase --> monitor de TV
# Speed: 4.7ms preprocess, 232.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.0ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 4.5ms preprocess, 231.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 232.3ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Confianza ---> 0.26
# Nombre de la clase --> persona
# Speed: 4.0ms preprocess, 232.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.7ms
# Confianza ---> 0.88
# Nombre de la clase --> persona
# Speed: 6.0ms preprocess, 229.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
